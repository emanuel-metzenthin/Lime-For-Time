# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.metrics import accuracy_score as acc
import numpy as np
from lime import explanation
from lime import lime_base
from lime_timeseries import LimeTimeSeriesExplanation

# %%
coffee_train = pd.read_csv('coffee_train.csv', sep=',', header=None)
coffee_train_y = coffee_train.loc[:, 0]
coffee_train_x = coffee_train.loc[:, 1:]
coffee_test = pd.read_csv('coffee_test.csv', sep=',', header=None)
coffee_test_y = coffee_test.loc[:, 0]
coffee_test_x = coffee_test.loc[:, 1:]

# %% [markdown]
# ## Coffee Dataset

# %%
for idx in range(0, len(coffee_train)):
    if coffee_train_y[idx] == 0:
        plt.plot(coffee_train_x.loc[idx, :], 'b')
    else:
        plt.plot(coffee_train_x.loc[idx, :], 'r')
plt.show()

# %% [markdown]
# ### Compute Accuracy

# %%
knn = KNN()
knn.fit(coffee_train_x, coffee_train_y)
acc(coffee_test_y, knn.predict(coffee_test_x))
# Out:
# 0.9642857142857143

# %%
idx = 20
explainer = LimeTimeSeriesExplanation(class_names=['0', '1'])
exp = explainer.explain_instance(coffee_test_x[idx], knn.predict_proba, num_features=len(coffee_train_x[0]), training_set=coffee_train_x)
print('Document id: %d' % idx)
print('Probability(christian) =', c.predict_proba([newsgroups_test.data[idx]])[0,1])
print('True class: %s' % class_names[newsgroups_test.target[idx]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-a6db3623cf7e> in <module>()
#       1 idx = 20
#       2 explainer = lime_timeseries.LimeTimeSeriesExplanation(class_names=['0', '1'])
# ----> 3 exp = explainer.explain_instance(coffee_test_x[idx], knn.predict_proba, num_features=len(coffee_train_x[0]), training_set=coffee_train_x)
#       4 print('Document id: %d' % idx)
#       5 print('Probability(christian) =', c.predict_proba([newsgroups_test.data[idx]])[0,1])
#
# AttributeError: 'LimeTimeSeriesExplanation' object has no attribute 'explain_instance'
